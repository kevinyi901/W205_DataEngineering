# %%
import math
import numpy as np
import pandas as pd
import csv

import psycopg2

from geographiclib.geodesic import Geodesic

import neo4j

from IPython.display import display
pd.set_option('display.max_rows', None)  # Show all rows

# %% [markdown]
# # Rank BART Stations by proximity to zipcodes and population size

# %%
# Load station information
df = pd.read_csv('stations.csv')

# Creating a list of station names
first_column_list = df.iloc[:, 0].tolist()

# Display the list
print(first_column_list)
# Out:
# ['12th Street', '16th Street Mission', '19th Street', '24th Street Mission', 'Antioch', 'Ashby', 'Balboa Park', 'Bay Fair', 'Berryessa', 'Castro Valley', 'Civic Center', 'Coliseum', 'Colma', 'Concord', 'Daly City', 'Downtown Berkeley', 'Dublin', 'El Cerrito Plaza', 'El Cerrito del Norte', 'Embarcadero', 'Fremont', 'Fruitvale', 'Glen Park', 'Hayward', 'Lafayette', 'Lake Merritt', 'MacArthur', 'Millbrae', 'Milpitas', 'Montgomery Street', 'North Berkeley', 'North Concord', 'OAK', 'Orinda', 'Pittsburg', 'Pittsburg Center', 'Pleasant Hill', 'Powell Street', 'Richmond', 'Rockridge', 'SFO', 'San Bruno', 'San Leandro', 'South Hayward', 'South San Francisco', 'Union City', 'Walnut Creek', 'Warm Springs', 'West Dublin', 'West Oakland']

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %%
def my_calculate_box(point, miles):
    "Given a point and miles, calculate the box in form left, right, top, bottom"
    
    geod = Geodesic.WGS84

    kilometers = miles * 1.60934
    meters = kilometers * 1000

    g = geod.Direct(point[0], point[1], 270, meters)
    left = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 90, meters)
    right = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 0, meters)
    top = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 180, meters)
    bottom = (g['lat2'], g['lon2'])
    
    return(left, right, top, bottom)

# %%
def get_stations_ordered_by_zip_and_population():
    """Identify and order stations by the number of zip codes and population within each station's area."""

    # Query to get station data
    query_stations = "SELECT station, latitude, longitude FROM stations"
    cursor.execute(query_stations)
    stations = cursor.fetchall()
    
    if not stations:
        print("No stations found.")
        return

    # Dictionary to store results
    station_stats = {}

    for station, latitude, longitude in stations:
        # Calculate the boundary box for the desired radius (e.g., miles)
        point = (latitude, longitude)
        left, right, top, bottom = my_calculate_box(point, miles=3)  # Adjust the distance as needed

        # Query to get zip codes and populations within the area
        query_zips = """
            SELECT zip, population FROM zip_codes
            WHERE latitude >= %s AND latitude <= %s
              AND longitude >= %s AND longitude <= %s
        """
        cursor.execute(query_zips, (bottom[0], top[0], left[1], right[1]))
        zips = cursor.fetchall()
        
        # Calculate statistics
        num_zips = len(zips)
        total_population = sum(pop for _, pop in zips)

        # Store results
        station_stats[station] = {"num_zips": num_zips, "total_population": total_population}

    # Sort stations by number of zip codes and population
    sorted_stations = sorted(
        station_stats.items(),
        key=lambda x: (x[1]["num_zips"], x[1]["total_population"]),
        reverse=True
    )

    # Display the results
    print("\n-------------------------------------------------------------------------------")
    print("  Stations Ordered by Number of Zip Codes and Population")
    print("-------------------------------------------------------------------------------\n")
    for station, stats in sorted_stations:
        print(f"Station: {station}, Zip Codes: {stats['num_zips']}, Population: {stats['total_population']:10,}")
    print("\n-------------------------------------------------------------------------------")

# Call the function
get_stations_ordered_by_zip_and_population()
# Out:
# -------------------------------------------------------------------------------
#   Stations Ordered by Number of Zip Codes and Population
# -------------------------------------------------------------------------------
#
# Station: 16th Street Mission, Zip Codes: 20, Population:    554,106
# Station: Civic Center, Zip Codes: 19, Population:    500,384
# Station: 24th Street Mission, Zip Codes: 18, Population:    621,661
# Station: Powell Street, Zip Codes: 18, Population:    496,390
# Station: Embarcadero, Zip Codes: 16, Population:    425,020
# Station: Montgomery Street, Zip Codes: 16, Population:    425,020
# Station: Glen Park, Zip Codes: 15, Population:    624,151
# Station: Rockridge, Zip Codes: 15, Population:    317,026
# Station: Downtown Berkeley, Zip Codes: 13, Population:    218,308
# Station: North Berkeley, Zip Codes: 13, Population:    218,308
# Station: Balboa Park, Zip Codes: 12, Population:    548,413
# Station: MacArthur, Zip Codes: 12, Population:    271,301
# Station: Ashby, Zip Codes: 12, Population:    226,433
# Station: El Cerrito Plaza, Zip Codes: 12, Population:    216,274
# Station: Fruitvale, Zip Codes: 10, Population:    317,296
# Station: 12th Street, Zip Codes: 9, Population:    298,398
# Station: 19th Street, Zip Codes: 9, Population:    298,398
# Station: Berryessa, Zip Codes: 8, Population:    293,347
# Station: Lake Merritt, Zip Codes: 8, Population:    281,357
# Station: Coliseum, Zip Codes: 8, Population:    267,162
# Station: Daly City, Zip Codes: 7, Population:    330,204
# Station: Bay Fair, Zip Codes: 7, Population:    286,050
# Station: West Oakland, Zip Codes: 7, Population:    229,058
# Station: Colma, Zip Codes: 6, Population:    341,124
# Station: San Leandro, Zip Codes: 6, Population:    224,179
# Station: El Cerrito del Norte, Zip Codes: 6, Population:    140,593
# Station: Hayward, Zip Codes: 5, Population:    230,509
# Station: South San Francisco, Zip Codes: 5, Population:    229,815
# Station: Richmond, Zip Codes: 5, Population:    175,840
# Station: OAK, Zip Codes: 5, Population:    154,627
# Station: South Hayward, Zip Codes: 4, Population:    234,109
# Station: Castro Valley, Zip Codes: 4, Population:    165,604
# Station: Milpitas, Zip Codes: 4, Population:    164,682
# Station: SFO, Zip Codes: 4, Population:    133,566
# Station: San Bruno, Zip Codes: 4, Population:    133,566
# Station: Concord, Zip Codes: 4, Population:    122,213
# Station: Millbrae, Zip Codes: 4, Population:    108,699
# Station: Pleasant Hill, Zip Codes: 4, Population:    107,080
# Station: Walnut Creek, Zip Codes: 4, Population:     91,133
# Station: Union City, Zip Codes: 3, Population:    227,691
# Station: Warm Springs, Zip Codes: 2, Population:    120,913
# Station: Fremont, Zip Codes: 2, Population:    120,131
# Station: Antioch, Zip Codes: 2, Population:    110,721
# Station: Dublin, Zip Codes: 2, Population:     90,736
# Station: West Dublin, Zip Codes: 2, Population:     90,736
# Station: North Concord, Zip Codes: 2, Population:     58,689
# Station: Lafayette, Zip Codes: 2, Population:     52,373
# Station: Orinda, Zip Codes: 2, Population:     32,706
# Station: Pittsburg, Zip Codes: 1, Population:     96,081
# Station: Pittsburg Center, Zip Codes: 1, Population:     96,081
#
# -------------------------------------------------------------------------------

# %% [markdown]
# #  LOUVAIN MODULARITY
# Group the stations into communities, and then within each community, decide which station to add a distribution / distribution point.

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","ucb_mids_w205"))

# %%
session = driver.session(database="neo4j")

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df

# %%
query = "CALL gds.graph.drop('ds_graph', false) yield graphName"
session.run(query)

query = """

CALL gds.graph.project('ds_graph', 'Station', 'LINK', 
                      {relationshipProperties: 'weight'})
"""

session.run(query)

# %%
query = """

CALL gds.louvain.stream('ds_graph', {includeIntermediateCommunities: true})
YIELD nodeId, communityId, intermediateCommunityIds
RETURN gds.util.asNode(nodeId).name AS name, communityId as community, intermediateCommunityIds as intermediate_community
ORDER BY community, name ASC

"""

my_neo4j_run_query_pandas(query)
# Out:
#                             name  community intermediate_community
# 0     arrive 16th Street Mission          7              [3, 7, 7]
# 1     arrive 24th Street Mission          7              [7, 7, 7]
# 2       blue 16th Street Mission          7              [3, 7, 7]
# 3       blue 24th Street Mission          7              [7, 7, 7]
# 4     depart 16th Street Mission          7              [3, 7, 7]
# 5     depart 24th Street Mission          7              [7, 7, 7]
# 6      green 16th Street Mission          7              [3, 7, 7]
# 7      green 24th Street Mission          7              [7, 7, 7]
# 8        red 16th Street Mission          7              [3, 7, 7]
# 9        red 24th Street Mission          7              [7, 7, 7]
# 10    yellow 16th Street Mission          7              [3, 7, 7]
# 11    yellow 24th Street Mission          7              [7, 7, 7]
# 12           arrive Civic Center         21           [21, 21, 21]
# 13          arrive Powell Street         21           [75, 21, 21]
# 14             blue Civic Center         21           [21, 21, 21]
# 15            blue Powell Street         21           [75, 21, 21]
# 16           depart Civic Center         21           [21, 21, 21]
# 17          depart Powell Street         21           [75, 21, 21]
# 18            green Civic Center         21           [21, 21, 21]
# 19           green Powell Street         21           [75, 21, 21]
# 20              red Civic Center         21           [21, 21, 21]
# 21             red Powell Street         21           [75, 21, 21]
# 22           yellow Civic Center         21           [21, 21, 21]
# 23          yellow Powell Street         21           [75, 21, 21]
# 24            arrive Balboa Park         29           [13, 29, 29]
# 25              arrive Daly City         29           [29, 29, 29]
# 26              arrive Glen Park         29           [45, 29, 29]
# 27              blue Balboa Park         29           [13, 29, 29]
# 28                blue Daly City         29           [29, 29, 29]
# 29                blue Glen Park         29           [45, 29, 29]
# 30            depart Balboa Park         29           [13, 29, 29]
# 31              depart Daly City         29           [29, 29, 29]
# 32              depart Glen Park         29           [45, 29, 29]
# 33             green Balboa Park         29           [13, 29, 29]
# 34               green Daly City         29           [29, 29, 29]
# 35               green Glen Park         29           [45, 29, 29]
# 36               red Balboa Park         29           [13, 29, 29]
# 37                 red Daly City         29           [29, 29, 29]
# 38                 red Glen Park         29           [45, 29, 29]
# 39            yellow Balboa Park         29           [13, 29, 29]
# 40              yellow Daly City         29           [29, 29, 29]
# 41              yellow Glen Park         29           [45, 29, 29]
# 42                  arrive Ashby         31           [11, 31, 31]
# 43      arrive Downtown Berkeley         31           [31, 31, 31]
# 44       arrive El Cerrito Plaza         31           [37, 77, 31]
# 45   arrive El Cerrito del Norte         31           [35, 77, 31]
# 46         arrive North Berkeley         31           [61, 31, 31]
# 47               arrive Richmond         31           [77, 77, 31]
# 48                  depart Ashby         31           [11, 31, 31]
# 49      depart Downtown Berkeley         31           [31, 31, 31]
# 50       depart El Cerrito Plaza         31           [37, 77, 31]
# 51   depart El Cerrito del Norte         31           [35, 77, 31]
# 52         depart North Berkeley         31           [61, 31, 31]
# 53               depart Richmond         31           [77, 77, 31]
# 54                  orange Ashby         31           [11, 31, 31]
# 55      orange Downtown Berkeley         31           [31, 31, 31]
# 56       orange El Cerrito Plaza         31           [37, 77, 31]
# 57   orange El Cerrito del Norte         31           [35, 77, 31]
# 58         orange North Berkeley         31           [61, 31, 31]
# 59               orange Richmond         31           [77, 77, 31]
# 60                     red Ashby         31           [11, 31, 31]
# 61         red Downtown Berkeley         31           [31, 31, 31]
# 62          red El Cerrito Plaza         31           [37, 77, 31]
# 63      red El Cerrito del Norte         31           [35, 77, 31]
# 64            red North Berkeley         31           [61, 31, 31]
# 65                  red Richmond         31           [77, 77, 31]
# 66               arrive Bay Fair         47           [15, 83, 47]
# 67          arrive Castro Valley         47           [19, 97, 47]
# 68                 arrive Dublin         47           [33, 97, 47]
# 69                arrive Hayward         47           [47, 47, 47]
# 70            arrive San Leandro         47           [83, 83, 47]
# 71          arrive South Hayward         47           [87, 47, 47]
# 72            arrive West Dublin         47           [97, 97, 47]
# 73                 blue Bay Fair         47           [15, 83, 47]
# 74            blue Castro Valley         47           [19, 97, 47]
# 75                   blue Dublin         47           [33, 97, 47]
# 76              blue San Leandro         47           [83, 83, 47]
# 77              blue West Dublin         47           [97, 97, 47]
# 78               depart Bay Fair         47           [15, 83, 47]
# 79          depart Castro Valley         47           [19, 97, 47]
# 80                 depart Dublin         47           [33, 97, 47]
# 81                depart Hayward         47           [47, 47, 47]
# 82            depart San Leandro         47           [83, 83, 47]
# 83          depart South Hayward         47           [87, 47, 47]
# 84            depart West Dublin         47           [97, 97, 47]
# 85                green Bay Fair         47           [15, 83, 47]
# 86                 green Hayward         47           [47, 47, 47]
# 87             green San Leandro         47           [83, 83, 47]
# 88           green South Hayward         47           [87, 47, 47]
# 89               orange Bay Fair         47           [15, 83, 47]
# 90                orange Hayward         47           [47, 47, 47]
# 91            orange San Leandro         47           [83, 83, 47]
# 92          orange South Hayward         47           [87, 47, 47]
# 93               arrive Coliseum         51           [23, 51, 51]
# 94              arrive Fruitvale         51           [43, 51, 51]
# 95           arrive Lake Merritt         51           [51, 51, 51]
# 96                    arrive OAK         51           [65, 51, 51]
# 97                 blue Coliseum         51           [23, 51, 51]
# 98                blue Fruitvale         51           [43, 51, 51]
# 99             blue Lake Merritt         51           [51, 51, 51]
# 100              depart Coliseum         51           [23, 51, 51]
# 101             depart Fruitvale         51           [43, 51, 51]
# 102          depart Lake Merritt         51           [51, 51, 51]
# 103                   depart OAK         51           [65, 51, 51]
# 104                gray Coliseum         51           [23, 51, 51]
# 105                     gray OAK         51           [65, 51, 51]
# 106               green Coliseum         51           [23, 51, 51]
# 107              green Fruitvale         51           [43, 51, 51]
# 108           green Lake Merritt         51           [51, 51, 51]
# 109              orange Coliseum         51           [23, 51, 51]
# 110             orange Fruitvale         51           [43, 51, 51]
# 111          orange Lake Merritt         51           [51, 51, 51]
# 112           arrive Embarcadero         59           [39, 59, 59]
# 113     arrive Montgomery Street         59           [59, 59, 59]
# 114          arrive West Oakland         59           [99, 59, 59]
# 115             blue Embarcadero         59           [39, 59, 59]
# 116       blue Montgomery Street         59           [59, 59, 59]
# 117            blue West Oakland         59           [99, 59, 59]
# 118           depart Embarcadero         59           [39, 59, 59]
# 119     depart Montgomery Street         59           [59, 59, 59]
# 120          depart West Oakland         59           [99, 59, 59]
# 121            green Embarcadero         59           [39, 59, 59]
# 122      green Montgomery Street         59           [59, 59, 59]
# 123           green West Oakland         59           [99, 59, 59]
# 124              red Embarcadero         59           [39, 59, 59]
# 125        red Montgomery Street         59           [59, 59, 59]
# 126             red West Oakland         59           [99, 59, 59]
# 127           yellow Embarcadero         59           [39, 59, 59]
# 128     yellow Montgomery Street         59           [59, 59, 59]
# 129          yellow West Oakland         59           [99, 59, 59]
# 130               arrive Antioch         63            [9, 71, 63]
# 131               arrive Concord         63           [27, 63, 63]
# 132             arrive Lafayette         63           [49, 67, 63]
# 133         arrive North Concord         63           [63, 63, 63]
# 134                arrive Orinda         63           [67, 67, 63]
# 135             arrive Pittsburg         63           [69, 71, 63]
# 136      arrive Pittsburg Center         63           [71, 71, 63]
# 137         arrive Pleasant Hill         63           [73, 93, 63]
# 138             arrive Rockridge         63           [79, 67, 63]
# 139          arrive Walnut Creek         63           [93, 93, 63]
# 140               depart Antioch         63            [9, 71, 63]
# 141               depart Concord         63           [27, 63, 63]
# 142             depart Lafayette         63           [49, 67, 63]
# 143         depart North Concord         63           [63, 63, 63]
# 144                depart Orinda         63           [67, 67, 63]
# 145             depart Pittsburg         63           [69, 71, 63]
# 146      depart Pittsburg Center         63           [71, 71, 63]
# 147         depart Pleasant Hill         63           [73, 93, 63]
# 148             depart Rockridge         63           [79, 67, 63]
# 149          depart Walnut Creek         63           [93, 93, 63]
# 150               yellow Antioch         63            [9, 71, 63]
# 151               yellow Concord         63           [27, 63, 63]
# 152             yellow Lafayette         63           [49, 67, 63]
# 153         yellow North Concord         63           [63, 63, 63]
# 154                yellow Orinda         63           [67, 67, 63]
# 155             yellow Pittsburg         63           [69, 71, 63]
# 156      yellow Pittsburg Center         63           [71, 71, 63]
# 157         yellow Pleasant Hill         63           [73, 93, 63]
# 158             yellow Rockridge         63           [79, 67, 63]
# 159          yellow Walnut Creek         63           [93, 93, 63]
# 160           arrive 12th Street         67             [1, 5, 67]
# 161           arrive 19th Street         67             [5, 5, 67]
# 162             arrive MacArthur         67            [53, 5, 67]
# 163           depart 12th Street         67             [1, 5, 67]
# 164           depart 19th Street         67             [5, 5, 67]
# 165             depart MacArthur         67            [53, 5, 67]
# 166           orange 12th Street         67             [1, 5, 67]
# 167           orange 19th Street         67             [5, 5, 67]
# 168             orange MacArthur         67            [53, 5, 67]
# 169              red 12th Street         67             [1, 5, 67]
# 170              red 19th Street         67             [5, 5, 67]
# 171                red MacArthur         67            [53, 5, 67]
# 172           yellow 12th Street         67             [1, 5, 67]
# 173           yellow 19th Street         67             [5, 5, 67]
# 174             yellow MacArthur         67            [53, 5, 67]
# 175                 arrive Colma         85           [25, 89, 85]
# 176              arrive Millbrae         85           [55, 85, 85]
# 177                   arrive SFO         85           [85, 85, 85]
# 178             arrive San Bruno         85           [81, 85, 85]
# 179   arrive South San Francisco         85           [89, 89, 85]
# 180                 depart Colma         85           [25, 89, 85]
# 181              depart Millbrae         85           [55, 85, 85]
# 182                   depart SFO         85           [85, 85, 85]
# 183             depart San Bruno         85           [81, 85, 85]
# 184   depart South San Francisco         85           [89, 89, 85]
# 185                    red Colma         85           [25, 89, 85]
# 186                 red Millbrae         85           [55, 85, 85]
# 187                      red SFO         85           [85, 85, 85]
# 188                red San Bruno         85           [81, 85, 85]
# 189      red South San Francisco         85           [89, 89, 85]
# 190                 yellow Colma         85           [25, 89, 85]
# 191                   yellow SFO         85           [85, 85, 85]
# 192             yellow San Bruno         85           [81, 85, 85]
# 193   yellow South San Francisco         85           [89, 89, 85]
# 194             arrive Berryessa         91           [17, 57, 91]
# 195               arrive Fremont         91           [41, 91, 91]
# 196              arrive Milpitas         91           [57, 57, 91]
# 197            arrive Union City         91           [91, 91, 91]
# 198          arrive Warm Springs         91           [95, 57, 91]
# 199             depart Berryessa         91           [17, 57, 91]
# 200               depart Fremont         91           [41, 91, 91]
# 201              depart Milpitas         91           [57, 57, 91]
# 202            depart Union City         91           [91, 91, 91]
# 203          depart Warm Springs         91           [95, 57, 91]
# 204              green Berryessa         91           [17, 57, 91]
# 205                green Fremont         91           [41, 91, 91]
# 206               green Milpitas         91           [57, 57, 91]
# 207             green Union City         91           [91, 91, 91]
# 208           green Warm Springs         91           [95, 57, 91]
# 209             orange Berryessa         91           [17, 57, 91]
# 210               orange Fremont         91           [41, 91, 91]
# 211              orange Milpitas         91           [57, 57, 91]
# 212            orange Union City         91           [91, 91, 91]
# 213          orange Warm Springs         91           [95, 57, 91]
